# %%
import pandas as pd
from sqlalchemy import create_engine
from time import time

# %%
pd.__version__

# %%
df = pd.read_csv(
                 "green_tripdata_2019-09.csv"
                 ,nrows=0
                 ,low_memory=False
                 )

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
df_iter = pd.read_csv(
                      "green_tripdata_2019-09.csv"
                      ,iterator=True
                      ,chunksize=100000
                      ,low_memory=False
                      )

# %%
df.dtypes

# %%
df.to_sql(name='green_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
while True:
    t_start = time()

    df = next(df_iter)

    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

    df.to_sql(name='green_taxi_data', con=engine, if_exists='append')

    t_end = time()

    print('chunk inserted..., took %.3f second' % (t_end - t_start))
# Out:
# ---------------------------------------------------------------------------
# InvalidTextRepresentation                 Traceback (most recent call last)
# File ~/mambaforge/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2113, in Connection._exec_insertmany_context(self, dialect, context)
#    2112     else:
# -> 2113         dialect.do_execute(
#    2114             cursor,
#    2115             sub_stmt,
#    2116             sub_params,
#    2117             context,
#    2118         )
#    2120 except BaseException as e:
#
# File ~/mambaforge/lib/python3.10/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# InvalidTextRepresentation: invalid input syntax for type bigint: "N"
# LINE 1: ...53'::timestamp, '2019-09-01T00:23:46'::timestamp, 'N', 1, 65...
#                                                              ^
#
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# Cell In[27], line 9
#       6 df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
#       7 df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
# ----> 9 df.to_sql(name='green_taxi_data', con=engine, if_exists='append')
#      11 t_end = time()
#      13 print('chunk inserted..., took %.3f second' % (t_end - t_start))
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/generic.py:3008, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2813 """
#    2814 Write records stored in a DataFrame to a SQL database.
#    2815
#    (...)
#    3004 [(1,), (None,), (2,)]
#    3005 """  # noqa: E501
#    3006 from pandas.io import sql
# -> 3008 return sql.to_sql(
#    3009     self,
#    3010     name,
#    3011     con,
#    3012     schema=schema,
#    3013     if_exists=if_exists,
#    3014     index=index,
#    3015     index_label=index_label,
#    3016     chunksize=chunksize,
#    3017     dtype=dtype,
#    3018     method=method,
#    3019 )
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/io/sql.py:788, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     783     raise NotImplementedError(
#     784         "'frame' argument should be either a Series or a DataFrame"
#     785     )
#     787 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 788     return pandas_sql.to_sql(
#     789         frame,
#     790         name,
#     791         if_exists=if_exists,
#     792         index=index,
#     793         index_label=index_label,
#     794         schema=schema,
#     795         chunksize=chunksize,
#     796         dtype=dtype,
#     797         method=method,
#     798         engine=engine,
#     799         **engine_kwargs,
#     800     )
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/io/sql.py:1958, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1946 sql_engine = get_engine(engine)
#    1948 table = self.prep_table(
#    1949     frame=frame,
#    1950     name=name,
#    (...)
#    1955     dtype=dtype,
#    1956 )
# -> 1958 total_inserted = sql_engine.insert_records(
#    1959     table=table,
#    1960     con=self.con,
#    1961     frame=frame,
#    1962     name=name,
#    1963     index=index,
#    1964     schema=schema,
#    1965     chunksize=chunksize,
#    1966     method=method,
#    1967     **engine_kwargs,
#    1968 )
#    1970 self.check_case_sensitive(name=name, schema=schema)
#    1971 return total_inserted
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/io/sql.py:1507, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1505 if re.search(msg, err_text):
#    1506     raise ValueError("inf cannot be used with MySQL") from err
# -> 1507 raise err
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/io/sql.py:1498, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1495 from sqlalchemy import exc
#    1497 try:
# -> 1498     return table.insert(chunksize=chunksize, method=method)
#    1499 except exc.StatementError as err:
#    1500     # GH34431
#    1501     # https://stackoverflow.com/a/67358288/6067848
#    1502     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1503     )|inf can not be used with MySQL"""
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/io/sql.py:1059, in SQLTable.insert(self, chunksize, method)
#    1056     break
#    1058 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1059 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1060 # GH 46891
#    1061 if num_inserted is not None:
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/io/sql.py:951, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     939 """
#     940 Execute SQL statement inserting data
#     941
#    (...)
#     948    Each item contains a list of values to be inserted
#     949 """
#     950 data = [dict(zip(keys, row)) for row in data_iter]
# --> 951 result = conn.execute(self.table.insert(), data)
#     952 return result.rowcount
#
# File ~/mambaforge/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File ~/mambaforge/lib/python3.10/site-packages/sqlalchemy/sql/elements.py:517, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     515     if TYPE_CHECKING:
#     516         assert isinstance(self, Executable)
# --> 517     return connection._execute_clauseelement(
#     518         self, distilled_params, execution_options
#     519     )
#     520 else:
#     521     raise exc.ObjectNotExecutableError(self)
#
# File ~/mambaforge/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1639, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1627 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1628     "compiled_cache", self.engine._compiled_cache
#    1629 )
#    1631 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1632     dialect=dialect,
#    1633     compiled_cache=compiled_cache,
#    (...)
#    1637     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1638 )
# -> 1639 ret = self._execute_context(
#    1640     dialect,
#    1641     dialect.execution_ctx_cls._init_compiled,
#    1642     compiled_sql,
#    1643     distilled_parameters,
#    1644     execution_options,
#    1645     compiled_sql,
#    1646     distilled_parameters,
#    1647     elem,
#    1648     extracted_params,
#    1649     cache_hit=cache_hit,
#    1650 )
#    1651 if has_events:
#    1652     self.dispatch.after_execute(
#    1653         self,
#    1654         elem,
#    (...)
#    1658         ret,
#    1659     )
#
# File ~/mambaforge/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1843, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1840 context.pre_exec()
#    1842 if context.execute_style is ExecuteStyle.INSERTMANYVALUES:
# -> 1843     return self._exec_insertmany_context(
#    1844         dialect,
#    1845         context,
#    1846     )
#    1847 else:
#    1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File ~/mambaforge/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2121, in Connection._exec_insertmany_context(self, dialect, context)
#    2113         dialect.do_execute(
#    2114             cursor,
#    2115             sub_stmt,
#    2116             sub_params,
#    2117             context,
#    2118         )
#    2120 except BaseException as e:
# -> 2121     self._handle_dbapi_exception(
#    2122         e,
#    2123         sql_util._long_statement(sub_stmt),
#    2124         sub_params,
#    2125         cursor,
#    2126         context,
#    2127         is_sub_exec=True,
#    2128     )
#    2130 if engine_events:
#    2131     self.dispatch.after_cursor_execute(
#    2132         self,
#    2133         cursor,
#    (...)
#    2137         context.executemany,
#    2138     )
#
# File ~/mambaforge/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2344, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2342 elif should_wrap:
#    2343     assert sqlalchemy_exception is not None
# -> 2344     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2345 else:
#    2346     assert exc_info[1] is not None
#
# File ~/mambaforge/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2113, in Connection._exec_insertmany_context(self, dialect, context)
#    2111             break
#    2112     else:
# -> 2113         dialect.do_execute(
#    2114             cursor,
#    2115             sub_stmt,
#    2116             sub_params,
#    2117             context,
#    2118         )
#    2120 except BaseException as e:
#    2121     self._handle_dbapi_exception(
#    2122         e,
#    2123         sql_util._long_statement(sub_stmt),
#    (...)
#    2127         is_sub_exec=True,
#    2128     )
#
# File ~/mambaforge/lib/python3.10/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# DataError: (psycopg2.errors.InvalidTextRepresentation) invalid input syntax for type bigint: "N"
# LINE 1: ...53'::timestamp, '2019-09-01T00:23:46'::timestamp, 'N', 1, 65...
#                                                              ^
#
# [SQL: INSERT INTO green_taxi_data (index, "VendorID", lpep_pickup_datetime, lpep_dropoff_datetime, store_and_fwd_flag, "RatecodeID", "PULocationID", "DOLocationID", passenger_count, trip_distance, fare_amount, extra, mta_tax, tip_amount, tolls_amount, ehai ... 492686 characters truncated ... )s, %(total_amount__999)s, %(payment_type__999)s, %(trip_type__999)s, %(congestion_surcharge__999)s)]
# [parameters: {'DOLocationID__0': 189, 'tip_amount__0': 2.36, 'passenger_count__0': 5, 'ehail_fee__0': None, 'lpep_pickup_datetime__0': datetime.datetime(2019, 9, 1, 0, 10, 53), 'mta_tax__0': 0.5, 'payment_type__0': 1, 'lpep_dropoff_datetime__0': datetime.datetime(2019, 9, 1, 0, 23, 46), 'fare_amount__0': 10.5, 'trip_type__0': 1, 'total_amount__0': 14.16, 'congestion_surcharge__0': 0.0, 'tolls_amount__0': 0.0, 'extra__0': 0.5, 'store_and_fwd_flag__0': 'N', 'trip_distance__0': 2.0, 'VendorID__0': 2, 'index__0': 0, 'PULocationID__0': 65, 'RatecodeID__0': 1, 'improvement_surcharge__0': 0.3, 'DOLocationID__1': 225, 'tip_amount__1': 0.0, 'passenger_count__1': 5, 'ehail_fee__1': None, 'lpep_pickup_datetime__1': datetime.datetime(2019, 9, 1, 0, 31, 22), 'mta_tax__1': 0.5, 'payment_type__1': 2, 'lpep_dropoff_datetime__1': datetime.datetime(2019, 9, 1, 0, 44, 37), 'fare_amount__1': 12.0, 'trip_type__1': 1, 'total_amount__1': 13.3, 'congestion_surcharge__1': 0.0, 'tolls_amount__1': 0.0, 'extra__1': 0.5, 'store_and_fwd_flag__1': 'N', 'trip_distance__1': 3.2, 'VendorID__1': 2, 'index__1': 1, 'PULocationID__1': 97, 'RatecodeID__1': 1, 'improvement_surcharge__1': 0.3, 'DOLocationID__2': 61, 'tip_amount__2': 0.0, 'passenger_count__2': 5, 'ehail_fee__2': None, 'lpep_pickup_datetime__2': datetime.datetime(2019, 9, 1, 0, 50, 24), 'mta_tax__2': 0.5, 'payment_type__2': 2, 'lpep_dropoff_datetime__2': datetime.datetime(2019, 9, 1, 1, 3, 20) ... 20900 parameters truncated ... 'extra__997': 0.5, 'store_and_fwd_flag__997': 'N', 'trip_distance__997': 1.54, 'VendorID__997': 2, 'index__997': 997, 'PULocationID__997': 255, 'RatecodeID__997': 1, 'improvement_surcharge__997': 0.3, 'DOLocationID__998': 53, 'tip_amount__998': 4.7, 'passenger_count__998': 1, 'ehail_fee__998': None, 'lpep_pickup_datetime__998': datetime.datetime(2019, 9, 1, 1, 29, 41), 'mta_tax__998': 0.5, 'payment_type__998': 1, 'lpep_dropoff_datetime__998': datetime.datetime(2019, 9, 1, 1, 42, 1), 'fare_amount__998': 17.5, 'trip_type__998': 1, 'total_amount__998': 23.5, 'congestion_surcharge__998': 0.0, 'tolls_amount__998': 0.0, 'extra__998': 0.5, 'store_and_fwd_flag__998': 'N', 'trip_distance__998': 5.41, 'VendorID__998': 2, 'index__998': 998, 'PULocationID__998': 93, 'RatecodeID__998': 1, 'improvement_surcharge__998': 0.3, 'DOLocationID__999': 41, 'tip_amount__999': 0.0, 'passenger_count__999': 1, 'ehail_fee__999': None, 'lpep_pickup_datetime__999': datetime.datetime(2019, 9, 1, 1, 11, 28), 'mta_tax__999': 0.5, 'payment_type__999': 2, 'lpep_dropoff_datetime__999': datetime.datetime(2019, 9, 1, 1, 11, 36), 'fare_amount__999': 2.5, 'trip_type__999': 1, 'total_amount__999': 3.8, 'congestion_surcharge__999': 0.0, 'tolls_amount__999': 0.0, 'extra__999': 0.5, 'store_and_fwd_flag__999': 'N', 'trip_distance__999': 0.03, 'VendorID__999': 2, 'index__999': 999, 'PULocationID__999': 41, 'RatecodeID__999': 1, 'improvement_surcharge__999': 0.3}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)

# %%
df_b = pd.read_csv('taxi+_zone_lookup.csv')

# %%
df_b.to_sql(name='taxi_zone_lookup', con=engine, if_exists='replace')
